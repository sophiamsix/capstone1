# %%
#Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import dataframe_image as dfi
from wordcloud import WordCloud, STOPWORDS
from collections import Counter, defaultdict
from tqdm import tqdm
import spacy
spacy.load('en_core_web_sm')

import convokit
from convokit import Corpus, Speaker, Utterance, download, TextParser, PolitenessStrategies

import nltk
from nltk import word_tokenize, Text, WordNetLemmatizer, FreqDist, pos_tag
from nltk.corpus import stopwords, names, subjectivity
from nltk.stem import WordNetLemmatizer
from nltk.classify import NaiveBayesClassifier
from nltk.sentiment import SentimentAnalyzer, SentimentIntensityAnalyzer
from nltk.sentiment.util import *

sid = SentimentIntensityAnalyzer()
wnl = WordNetLemmatizer()
parser = TextParser(verbosity=1000)
ps = PolitenessStrategies()
stop_words = set(stopwords.words("english")+ ["'nt", "'re", "'m", "n't", "'s", "'ll", "'ve", "'d"])

# %%
#Read in Data
conversations = pd.read_csv("data/movie_conversations.tsv", names=["character_id_1", "character_id_2", "movie_id", "line_id_list"], sep="\t", header=None, error_bad_lines=False)
characters = pd.read_table("data/movie_characters_metadata.tsv", names=["character_id", "character_name", "movie_id", "movie_title", "gender", "position"], sep="\t", header=None, error_bad_lines=False)
lines = pd.read_csv("data/movie_lines.tsv", sep="\t", names=["line_id", "character_id", "movie_id", "character_name", "text"], header=None, error_bad_lines=False)
titles = pd.read_csv("data/movie_titles_metadata.tsv", names=["movie_id", "movie_title", "movie_year", "rating", "votes", "genres"], sep="\t", header=None, error_bad_lines=False)
urls = pd.read_csv("data/raw_script_urls.tsv", names=["movie_title", "url"], sep="\t", header=None, error_bad_lines=False)

# %%
conversations.head()
# Out:
#   character_id_1 character_id_2 movie_id                   line_id_list
# 0             u0             u2       m0  ['L194' 'L195' 'L196' 'L197']
# 1             u0             u2       m0                ['L198' 'L199']
# 2             u0             u2       m0  ['L200' 'L201' 'L202' 'L203']
# 3             u0             u2       m0         ['L204' 'L205' 'L206']
# 4             u0             u2       m0                ['L207' 'L208']

# %%
characters.head()
# Out:
#   character_id character_name movie_id                 movie_title gender  \
# 0           u0         BIANCA       m0  10 things i hate about you      f
# 1           u1          BRUCE       m0  10 things i hate about you      ?
# 2           u2        CAMERON       m0  10 things i hate about you      m
# 3           u3       CHASTITY       m0  10 things i hate about you      ?
# 4           u4           JOEY       m0  10 things i hate about you      m
#
#   position
# 0        4
# 1        ?
# 2        3
# 3        ?
# 4        6

# %%
lines.head()
# Out:
#   line_id character_id movie_id character_name          text
# 0   L1045           u0       m0         BIANCA  They do not!
# 1   L1044           u2       m0        CAMERON   They do to!
# 2    L985           u0       m0         BIANCA    I hope so.
# 3    L984           u2       m0        CAMERON     She okay?
# 4    L925           u0       m0         BIANCA     Let's go.

# %%
titles.head()
# Out:
#   movie_id                 movie_title movie_year  rating     votes  \
# 0       m0  10 things i hate about you       1999     6.9   62847.0
# 1       m1  1492: conquest of paradise       1992     6.2   10421.0
# 2       m2                  15 minutes       2001     6.1   25854.0
# 3       m3       2001: a space odyssey       1968     8.4  163227.0
# 4       m4                     48 hrs.       1982     6.9   22289.0
#
#                                            genres
# 0                            ['comedy' 'romance']
# 1     ['adventure' 'biography' 'drama' 'history']
# 2           ['action' 'crime' 'drama' 'thriller']
# 3                ['adventure' 'mystery' 'sci-fi']
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']

# %%
urls.head()
# Out:
#                    movie_title  \
# m0  10 things i hate about you
# m1  1492: conquest of paradise
# m2                  15 minutes
# m3       2001: a space odyssey
# m4                     48 hrs.
#
#                                                   url
# m0   http://www.dailyscript.com/scripts/10Things.html
# m1  http://www.hundland.org/scripts/1492-ConquestO...
# m2  http://www.dailyscript.com/scripts/15minutes.html
# m3       http://www.scifiscripts.com/scripts/2001.txt
# m4      http://www.awesomefilm.com/script/48hours.txt

# %%
#Merge all datasets
full_data = lines.merge(titles, on="movie_id", how="inner").merge(characters, on="character_id", how="inner")
full_data = full_data.drop(labels=["movie_id_y", "character_name_y", "movie_title_y"], axis=1) #Remove duplicates
full_data = full_data.rename(columns={"movie_id_x":"movie_id", "character_name_x":"character_name", "movie_title_x":"movie_title"}) #Clean titles from duplicates
full_data["gender"] = full_data["gender"].str.lower() #Clean gender data

# %%
#Identify more genders based on name, for characters with unlabeled gender
char_gender_corr = characters
characters["corrected_gender"] = characters["gender"]
full_data["corrected_gender"] = full_data["gender"]

# %%
#Males
for x in char_gender_corr["character_name"]:
    if full_data.loc[full_data.character_name == x, "gender"].any() == "?":
        if str(x).capitalize() in names.words('male.txt') and str(x).capitalize() not in names.words('female.txt'):
            full_data.loc[full_data.character_name == x, "corrected_gender"] = "m"
            characters.loc[characters.character_name == x, "corrected_gender"] = "m"

# %%
#Females
for x in char_gender_corr["character_name"]:
    if full_data.loc[full_data.character_name == x, "gender"].any() == "?":
        if str(x).capitalize() in names.words('female.txt') and str(x).capitalize() not in names.words('male.txt'):
            full_data.loc[full_data.character_name == x, "corrected_gender"] = "f"
            characters.loc[characters.character_name == x, "corrected_gender"] = "f"

# %%
def correct_name_gender(name, gender):
    full_data.loc[full_data.character_name == name, "corrected_gender"] = gender
    characters.loc[characters.character_name == name, "corrected_gender"] = gender

# %%
full_data.head()
# Out:
#   line_id character_id movie_id character_name  \
# 0   L1045           u0       m0         BIANCA
# 1    L985           u0       m0         BIANCA
# 2    L925           u0       m0         BIANCA
# 3    L872           u0       m0         BIANCA
# 4    L869           u0       m0         BIANCA
#
#                                              text                 movie_title  \
# 0                                    They do not!  10 things i hate about you
# 1                                      I hope so.  10 things i hate about you
# 2                                       Let's go.  10 things i hate about you
# 3  Okay -- you're gonna need to learn how to lie.  10 things i hate about you
# 4                Like my fear of wearing pastels?  10 things i hate about you
#
#   movie_year  rating    votes                genres gender position  \
# 0       1999     6.9  62847.0  ['comedy' 'romance']      f        4
# 1       1999     6.9  62847.0  ['comedy' 'romance']      f        4
# 2       1999     6.9  62847.0  ['comedy' 'romance']      f        4
# 3       1999     6.9  62847.0  ['comedy' 'romance']      f        4
# 4       1999     6.9  62847.0  ['comedy' 'romance']      f        4
#
#   corrected_gender
# 0                f
# 1                f
# 2                f
# 3                f
# 4                f

# %%
corr_gender_total = full_data.groupby("corrected_gender")["line_id"].count()

# %%
#Plot total lines by gender
plt.style.use('ggplot')
corr_gender_total.plot.bar()
plt.xticks(rotation=None)
plt.xlabel("Gender")
plt.title("Lines by Gender")
plt.tight_layout()
plt.savefig("images/lines_by_corr_gender.png", dpi=300)

# %%
#Plot total characters by gender
characters["corrected_gender"] = characters["corrected_gender"].str.lower()
characters.groupby("corrected_gender").count()["character_id"].plot.bar()
plt.xticks(rotation=None)
plt.title("Characters by Gender")
plt.xlabel("Gender")
plt.tight_layout()
plt.savefig("images/characters_by_corr_gender.png", dpi=300)

# %%
#Create list of genre names
genres_list = []
for x in full_data["genres"]:
    if x not in genres_list:
        genres_list.append(x)

# %%
#Remove punctuation
genres_list_np = []
punct = "[,']"
for i in range(len(genres_list)):
    for x in genres_list[i]:
        if x in punct:
            genres_list[i] = genres_list[i].replace(x, "")
    genres_list_np.append(genres_list[i])
genres_list_np = sorted(genres_list_np)

# %%
#Separate genres
genres_list_np = " ".join(genres_list_np)
genres_list_np.split(" ")
# Out:
# ['',
#  'action',
#  'action',
#  'adventure',
#  'action',
#  'adventure',
#  'adventure',
#  'adventure',
#  'sci-fi',
#  'action',
#  'adventure',
#  'animation',
#  'sci-fi',
#  'action',
#  'adventure',
#  'comedy',
#  'action',
#  'adventure',
#  'comedy',
#  'crime',
#  'action',
#  'adventure',
#  'comedy',
#  'crime',
#  'action',
#  'adventure',
#  'comedy',
#  'crime',
#  'sci-fi',
#  'action',
#  'adventure',
#  'comedy',
#  'drama',
#  'war',
#  'action',
#  'adventure',
#  'comedy',
#  'fantasy',
#  'sci-fi',
#  'action',
#  'adventure',
#  'comedy',
#  'fantasy',
#  'sci-fi',
#  'action',
#  'adventure',
#  'comedy',
#  'sci-fi',
#  'action',
#  'adventure',
#  'comedy',
#  'sci-fi',
#  'action',
#  'adventure',
#  'comedy',
#  'thriller',
#  'action',
#  'adventure',
#  'crime',
#  'action',
#  'adventure',
#  'crime',
#  'drama',
#  'sci-fi',
#  'action',
#  'adventure',
#  'crime',
#  'drama',
#  'sport',
#  'thriller',
#  'action',
#  'adventure',
#  'crime',
#  'horror',
#  'thriller',
#  'action',
#  'adventure',
#  'crime',
#  'thriller',
#  'action',
#  'adventure',
#  'drama',
#  'action',
#  'adventure',
#  'drama',
#  'fantasy',
#  'romance',
#  'action',
#  'adventure',
#  'drama',
#  'history',
#  'action',
#  'adventure',
#  'drama',
#  'history',
#  'war',
#  'action',
#  'adventure',
#  'drama',
#  'sci-fi',
#  'thriller',
#  'action',
#  'adventure',
#  'family',
#  'fantasy',
#  'sci-fi',
#  'action',
#  'adventure',
#  'family',
#  'sci-fi',
#  'action',
#  'adventure',
#  'fantasy',
#  'sci-fi',
#  'action',
#  'adventure',
#  'fantasy',
#  'action',
#  'adventure',
#  'fantasy',
#  'horror',
#  'thriller',
#  'action',
#  'adventure',
#  'fantasy',
#  'romance',
#  'sci-fi',
#  'action',
#  'adventure',
#  'fantasy',
#  'sci-fi',
#  'action',
#  'adventure',
#  'fantasy',
#  'sci-fi',
#  'action',
#  'adventure',
#  'sci-fi',
#  'thriller',
#  'action',
#  'adventure',
#  'fantasy',
#  'sci-fi',
#  'fantasy',
#  'action',
#  'adventure',
#  'mystery',
#  'thriller',
#  'action',
#  'adventure',
#  'romance',
#  'sci-fi',
#  'thriller',
#  'action',
#  'adventure',
#  'sci-fi',
#  'action',
#  'adventure',
#  'sci-fi',
#  'fantasy',
#  'action',
#  'adventure',
#  'sci-fi',
#  'thriller',
#  'action',
#  'adventure',
#  'sci-fi',
#  'thriller',
#  'action',
#  'adventure',
#  'animation',
#  'horror',
#  'sci-fi',
#  'thriller',
#  'action',
#  'adventure',
#  'sci-fi',
#  'thriller',
#  'animation',
#  'action',
#  'adventure',
#  'sci-fi',
#  'action',
#  'adventure',
#  'sci-fi',
#  'thriller',
#  'sci-fi',
#  'action',
#  'adventure',
#  'thriller',
#  'action',
#  'adventure',
#  'thriller',
#  'action',
#  'adventure',
#  'fantasy',
#  'action',
#  'adventure',
#  'war',
#  'action',
#  'biography',
#  'drama',
#  'history',
#  'war',
#  'action',
#  'comedy',
#  'crime',
#  'action',
#  'comedy',
#  'crime',
#  'drama',
#  'thriller',
#  'action',
#  'comedy',
#  'crime',
#  'romance',
#  'action',
#  'comedy',
#  'crime',
#  'thriller',
#  'action',
#  'comedy',
#  'fantasy',
#  'action',
#  'comedy',
#  'horror',
#  'thriller',
#  'action',
#  'comedy',
#  'thriller',
#  'crime',
#  'action',
#  'crime',
#  'drama',
#  'fantasy',
#  'music',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'action',
#  'crime',
#  'drama',
#  'horror',
#  'sci-fi',
#  'thriller',
#  'action',
#  'crime',
#  'drama',
#  'mystery',
#  'thriller',
#  'action',
#  'crime',
#  'drama',
#  'romance',
#  'thriller',
#  'action',
#  'crime',
#  'drama',
#  'sci-fi',
#  'thriller',
#  'action',
#  'crime',
#  'drama',
#  'thriller',
#  'action',
#  'crime',
#  'fantasy',
#  'action',
#  'crime',
#  'fantasy',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'action',
#  'crime',
#  'fantasy',
#  'mystery',
#  'thriller',
#  'action',
#  'crime',
#  'fantasy',
#  'thriller',
#  'action',
#  'crime',
#  'fantasy',
#  'thriller',
#  'animation',
#  'crime',
#  'fantasy',
#  'action',
#  'thriller',
#  'action',
#  'crime',
#  'horror',
#  'thriller',
#  'action',
#  'crime',
#  'mystery',
#  'romance',
#  'thriller',
#  'action',
#  'crime',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'action',
#  'animation',
#  'drama',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'action',
#  'crime',
#  'romance',
#  'thriller',
#  'action',
#  'crime',
#  'sci-fi',
#  'action',
#  'crime',
#  'sci-fi',
#  'thriller',
#  'action',
#  'crime',
#  'thriller',
#  'action',
#  'drama',
#  'action',
#  'drama',
#  'history',
#  'romance',
#  'western',
#  'action',
#  'drama',
#  'history',
#  'war',
#  'action',
#  'drama',
#  'romance',
#  'action',
#  'drama',
#  'romance',
#  'war',
#  'action',
#  'drama',
#  'romance',
#  'western',
#  'action',
#  'drama',
#  'sci-fi',
#  'action',
#  'drama',
#  'thriller',
#  'action',
#  'drama',
#  'war',
#  'action',
#  'family',
#  'action',
#  'family',
#  'sci-fi',
#  'action',
#  'fantasy',
#  'action',
#  'fantasy',
#  'horror',
#  'thriller',
#  'action',
#  'adventure',
#  'horror',
#  'action',
#  'horror',
#  'sci-fi',
#  'thriller',
#  'action',
#  'horror',
#  'thriller',
#  'action',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'action',
#  'sci-fi',
#  'action',
#  'sci-fi',
#  'thriller',
#  'action',
#  'thriller',
#  'action',
#  'thriller',
#  'crime',
#  'action',
#  'western',
#  'action',
#  'western',
#  'comedy',
#  'sci-fi',
#  'adventure',
#  'biography',
#  'drama',
#  'history',
#  'adventure',
#  'comedy',
#  'adventure',
#  'comedy',
#  'family',
#  'fantasy',
#  'romance',
#  'adventure',
#  'comedy',
#  'sci-fi',
#  'adventure',
#  'drama',
#  'adventure',
#  'drama',
#  'fantasy',
#  'adventure',
#  'drama',
#  'fantasy',
#  'mystery',
#  'adventure',
#  'drama',
#  'history',
#  'thriller',
#  'war',
#  'adventure',
#  'drama',
#  'horror',
#  'mystery',
#  'thriller',
#  'adventure',
#  'drama',
#  'romance',
#  'adventure',
#  'drama',
#  'romance',
#  'sci-fi',
#  'adventure',
#  'drama',
#  'romance',
#  'thriller',
#  'adventure',
#  'drama',
#  'sci-fi',
#  'adventure',
#  'drama',
#  'thriller',
#  'adventure',
#  'family',
#  'fantasy',
#  'musical',
#  'adventure',
#  'family',
#  'sci-fi',
#  'adventure',
#  'fantasy',
#  'horror',
#  'adventure',
#  'fantasy',
#  'mystery',
#  'sci-fi',
#  'adventure',
#  'horror',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'adventure',
#  'horror',
#  'sci-fi',
#  'thriller',
#  'adventure',
#  'mystery',
#  'sci-fi',
#  'adventure',
#  'romance',
#  'comedy',
#  'sci-fi',
#  'adventure',
#  'sci-fi',
#  'animation',
#  'adventure',
#  'action',
#  'fantasy',
#  'animation',
#  'adventure',
#  'comedy',
#  'crime',
#  'animation',
#  'adventure',
#  'comedy',
#  'family',
#  'animation',
#  'adventure',
#  'comedy',
#  'family',
#  'fantasy',
#  'animation',
#  'adventure',
#  'drama',
#  'family',
#  'musical',
#  'animation',
#  'family',
#  'animation',
#  'comedy',
#  'crime',
#  'family',
#  'fantasy',
#  'mystery',
#  'animation',
#  'adventure',
#  'action',
#  'fantasy',
#  'animation',
#  'comedy',
#  'fantasy',
#  'romance',
#  'animation',
#  'comedy',
#  'fantasy',
#  'sci-fi',
#  'horror',
#  'animation',
#  'comedy',
#  'musical',
#  'animation',
#  'family',
#  'fantasy',
#  'musical',
#  'biography',
#  'comedy',
#  'drama',
#  'biography',
#  'crime',
#  'drama',
#  'biography',
#  'crime',
#  'drama',
#  'thriller',
#  'biography',
#  'drama',
#  'biography',
#  'drama',
#  'history',
#  'biography',
#  'drama',
#  'history',
#  'mystery',
#  'thriller',
#  'biography',
#  'drama',
#  'history',
#  'romance',
#  'biography',
#  'drama',
#  'history',
#  'war',
#  'biography',
#  'drama',
#  'music',
#  'biography',
#  'drama',
#  'romance',
#  'biography',
#  'drama',
#  'sport',
#  'biography',
#  'drama',
#  'thriller',
#  'biography',
#  'drama',
#  'war',
#  'comedy',
#  'comedy',
#  'adult',
#  'comedy',
#  'adventure',
#  'crime',
#  'music',
#  'comedy',
#  'adventure',
#  'fantasy',
#  'comedy',
#  'crime',
#  'comedy',
#  'crime',
#  'drama',
#  'comedy',
#  'crime',
#  'drama',
#  'mystery',
#  'romance',
#  'comedy',
#  'crime',
#  'drama',
#  'thriller',
#  'comedy',
#  'crime',
#  'music',
#  'comedy',
#  'crime',
#  'mystery',
#  'comedy',
#  'crime',
#  'romance',
#  'comedy',
#  'crime',
#  'romance',
#  'thriller',
#  'comedy',
#  'crime',
#  'thriller',
#  'comedy',
#  'drama',
#  'comedy',
#  'drama',
#  'family',
#  'romance',
#  'comedy',
#  'drama',
#  'fantasy',
#  'comedy',
#  'drama',
#  'fantasy',
#  'romance',
#  'comedy',
#  'drama',
#  'music',
#  'comedy',
#  'drama',
#  'music',
#  'romance',
#  'comedy',
#  'drama',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'comedy',
#  'drama',
#  'romance',
#  'comedy',
#  'drama',
#  'romance',
#  'sport',
#  'comedy',
#  'drama',
#  'romance',
#  'western',
#  'comedy',
#  'drama',
#  'sport',
#  'comedy',
#  'family',
#  'comedy',
#  'fantasy',
#  'comedy',
#  'fantasy',
#  'drama',
#  'romance',
#  'comedy',
#  'fantasy',
#  'horror',
#  'comedy',
#  'fantasy',
#  'horror',
#  'thriller',
#  'comedy',
#  'fantasy',
#  'romance',
#  'comedy',
#  'horror',
#  'comedy',
#  'horror',
#  'sci-fi',
#  'comedy',
#  'horror',
#  'thriller',
#  'comedy',
#  'music',
#  'comedy',
#  'musical',
#  'comedy',
#  'musical',
#  'mystery',
#  'romance',
#  'comedy',
#  'mystery',
#  'romance',
#  'thriller',
#  'comedy',
#  'romance',
#  'comedy',
#  'romance',
#  'crime',
#  'comedy',
#  'romance',
#  'drama',
#  'comedy',
#  'romance',
#  'sci-fi',
#  'comedy',
#  'romance',
#  'sport',
#  'comedy',
#  'sci-fi',
#  'comedy',
#  'sci-fi',
#  'thriller',
#  'comedy',
#  'thriller',
#  'comedy',
#  'war',
#  'drama',
#  'crime',
#  'drama',
#  'crime',
#  'drama',
#  'fantasy',
#  'thriller',
#  'crime',
#  'drama',
#  'history',
#  'mystery',
#  'thriller',
#  'crime',
#  'drama',
#  'mystery',
#  'thriller',
#  'crime',
#  'drama',
#  'mystery',
#  'thriller',
#  'western',
#  'crime',
#  'drama',
#  'romance',
#  'crime',
#  'drama',
#  'romance',
#  'thriller',
#  'crime',
#  'drama',
#  'sci-fi',
#  'crime',
#  'drama',
#  'sci-fi',
#  'thriller',
#  'crime',
#  'drama',
#  'thriller',
#  'crime',
#  'drama',
#  'thriller',
#  'action',
#  'adventure',
#  'crime',
#  'crime',
#  'horror',
#  'crime',
#  'horror',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'crime',
#  'horror',
#  'mystery',
#  'thriller',
#  'crime',
#  'horror',
#  'sci-fi',
#  'thriller',
#  'crime',
#  'mystery',
#  'romance',
#  'thriller',
#  'crime',
#  'mystery',
#  'thriller',
#  'crime',
#  'mystery',
#  'thriller',
#  'western',
#  'crime',
#  'romance',
#  'thriller',
#  'crime',
#  'thriller',
#  'documentary',
#  'documentary',
#  'short',
#  'drama',
#  'drama',
#  'comedy',
#  'drama',
#  'crime',
#  'drama',
#  'crime',
#  'thriller',
#  'drama',
#  'fantasy',
#  'drama',
#  'fantasy',
#  'horror',
#  'drama',
#  'fantasy',
#  'horror',
#  'mystery',
#  'thriller',
#  'drama',
#  'fantasy',
#  'horror',
#  'sci-fi',
#  'thriller',
#  'drama',
#  'fantasy',
#  'mystery',
#  'romance',
#  'drama',
#  'fantasy',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'drama',
#  'fantasy',
#  'mystery',
#  'thriller',
#  'drama',
#  'fantasy',
#  'romance',
#  'drama',
#  'fantasy',
#  'sci-fi',
#  'drama',
#  'film-noir',
#  'drama',
#  'film-noir',
#  'thriller',
#  'drama',
#  'history',
#  'drama',
#  'history',
#  'romance',
#  'drama',
#  'history',
#  'thriller',
#  'drama',
#  'history',
#  'war',
#  'drama',
#  'horror',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'drama',
#  'horror',
#  'mystery',
#  'thriller',
#  'drama',
#  'horror',
#  'mystery',
#  'thriller',
#  'thriller',
#  'drama',
#  'horror',
#  'sci-fi',
#  'drama',
#  'horror',
#  'thriller',
#  'drama',
#  'horror',
#  'thriller',
#  'romance',
#  'drama',
#  'music',
#  'drama',
#  'music',
#  'romance',
#  'drama',
#  'music',
#  'war',
#  'drama',
#  'mystery',
#  'drama',
#  'mystery',
#  'romance',
#  'sci-fi',
#  'drama',
#  'mystery',
#  'romance',
#  'thriller',
#  'drama',
#  'mystery',
#  'romance',
#  'western',
#  'drama',
#  'mystery',
#  'sci-fi',
#  'drama',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'drama',
#  'mystery',
#  'thriller',
#  'drama',
#  'romance',
#  'drama',
#  'romance',
#  'sci-fi',
#  'drama',
#  'romance',
#  'sci-fi',
#  'thriller',
#  'drama',
#  'romance',
#  'sport',
#  'drama',
#  'romance',
#  'thriller',
#  'drama',
#  'romance',
#  'war',
#  'drama',
#  'romance',
#  'western',
#  'drama',
#  'sci-fi',
#  'thriller',
#  'drama',
#  'thriller',
#  'drama',
#  'war',
#  'drama',
#  'western',
#  'family',
#  'adventure',
#  'fantasy',
#  'fantasy',
#  'action',
#  'adventure',
#  'sci-fi',
#  'fantasy',
#  'adventure',
#  'romance',
#  'fantasy',
#  'comedy',
#  'romance',
#  'animation',
#  'comedy',
#  'fantasy',
#  'horror',
#  'fantasy',
#  'horror',
#  'fantasy',
#  'horror',
#  'mystery',
#  'thriller',
#  'fantasy',
#  'horror',
#  'thriller',
#  'fantasy',
#  'mystery',
#  'thriller',
#  'fantasy',
#  'sci-fi',
#  'action',
#  'film-noir',
#  'mystery',
#  'thriller',
#  'horror',
#  'horror',
#  'comedy',
#  'action',
#  'horror',
#  'mystery',
#  'mystery',
#  'sci-fi',
#  'sci-fi',
#  'horror',
#  'mystery',
#  'sci-fi',
#  'horror',
#  'mystery',
#  'sci-fi',
#  'thriller',
#  'horror',
#  'mystery',
#  'thriller',
#  'horror',
#  'romance',
#  'horror',
#  'romance',
#  'thriller',
#  'horror',
#  'romance',
#  'thriller',
#  'comedy',
#  'horror',
#  'sci-fi',
#  'horror',
#  ...]

# %%
#Create set from genres
genres_set = set(genres_list_np.split(" "))
genres_set.remove('')
genres_set
# Out:
# {'action',
#  'adult',
#  'adventure',
#  'animation',
#  'biography',
#  'comedy',
#  'crime',
#  'documentary',
#  'drama',
#  'family',
#  'fantasy',
#  'film-noir',
#  'history',
#  'horror',
#  'music',
#  'musical',
#  'mystery',
#  'romance',
#  'sci-fi',
#  'short',
#  'sport',
#  'thriller',
#  'war',
#  'western'}

# %%
titles = titles.dropna()
# Out:
#     movie_id                     movie_title movie_year  rating     votes  \
# 0    m0       10 things i hate about you      1999       6.9     62847.0
# 5    m5       the fifth element               1997       7.5     133756.0
# 12   m12      airplane ii: the sequel         1982       5.8     15210.0
# 13   m13      airplane!                       1980       7.8     57692.0
# 17   m17      an american werewolf in london  1981       7.5     24443.0
# ..   ...                                 ...   ...       ...         ...
# 576  m576     tombstone                       1993       7.7     44204.0
# 586  m586     true romance                    1993       7.9     74762.0
# 594  m594     vertigo                         1958       8.6     93524.0
# 608  m608     willow                          1988       7.1     33506.0
# 609  m609     witness                         1985       7.6     30705.0
#
#                                                    genres  percent_female
# 0    ['comedy' 'romance']                                  0.445652
# 5    ['action' 'adventure' 'romance' 'sci-fi' 'thriller']  0.151020
# 12   ['comedy' 'romance' 'sci-fi']                         0.450704
# 13   ['comedy' 'romance']                                  0.496296
# 17   ['horror' 'romance']                                  0.249027
# ..                    ...                                       ...
# 576  ['action' 'drama' 'history' 'romance' 'western']      0.153247
# 586  ['crime' 'romance' 'thriller']                        0.205686
# 594  ['crime' 'mystery' 'romance' 'thriller']              0.485893
# 608  ['action' 'adventure' 'drama' 'fantasy' 'romance']    0.172566
# 609  ['drama' 'romance' 'thriller']                        0.307453
#
# [128 rows x 7 columns]

# %%
#Make separate selections of dataframe containing each respective genre, contain selections in dictionary
def genre_df(genre):
    return full_data[full_data["genres"].str.contains(genre)]
def genre_title_df(genre):
    return titles[titles["genres"].str.contains(genre)]
    
genre_dict = dict()
genre_titles_dict = dict()
    
for x in genres_set:
    genre_dict[x] = genre_df(x)
    genre_titles_dict[x] = genre_title_df(x)

# %%
#Collect percentage of female to male lines by genre
percentages = dict()

def percent_gender(genre):
    if len(genre_dict[genre]["movie_id"].unique()) >= 10:
        percentages[genre] = (genre_dict[genre].groupby("corrected_gender")["line_id"].count()["f"])/((genre_dict[genre].groupby("corrected_gender")["line_id"].count()["m"]) + (genre_dict[genre].groupby("corrected_gender")["line_id"].count()["f"]))
        
for x in genres_set:
    percent_gender(x)

# %%
percentages
# Out:
# {'romance': 0.3645579947723873,
#  'crime': 0.2511392232877644,
#  'fantasy': 0.2919876088412592,
#  'history': 0.1612215909090909,
#  'comedy': 0.3085598461618419,
#  'animation': 0.20103537532355478,
#  'family': 0.3429080824088748,
#  'action': 0.22985092356120448,
#  'war': 0.147900025766555,
#  'adventure': 0.21232216059802267,
#  'horror': 0.3955164992826399,
#  'music': 0.24566088117489987,
#  'sci-fi': 0.25196383577886466,
#  'western': 0.25,
#  'biography': 0.2174813214510757,
#  'drama': 0.2936776742873271,
#  'mystery': 0.3005701941674412,
#  'thriller': 0.2854495867424479}

# %%
#Sorted by highest percentage of female lines
percentages_sort = dict(sorted(percentages.items(), key=lambda item: item[1], reverse=True))

# %%
#Plot percentage of female lines by genre
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(10,5))
x = np.arange(len(percentages_sort))
ax.bar(x, percentages_sort.values())
ax.set_xticks(x)
ax.set_xticklabels(list(percentages_sort.keys()), rotation=45, size=12)
ax.set_title("Percentage of Lines Spoken by Female Characters by Genre")
plt.tight_layout()
plt.savefig("images/lines_by_genre.png", dpi=300)

# %%
#Count percentage of total female lines in all movies
total_female_lines = (full_data.groupby("corrected_gender")["line_id"].count()["f"])/((full_data.groupby("corrected_gender")["line_id"].count()["m"]) + (full_data.groupby("corrected_gender")["line_id"].count()["f"]))

# %%
#Plot percentage of total female lines
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(10,5))
ax.pie([total_female_lines, (1-total_female_lines)], labels=["Female", "Male"])
ax.set_title("Total Percentage of Lines Spoken by Female Characters")
plt.savefig("images/total_female_lines.png")

# %%
top_female_movies = dict()

for i in range(617):
    indexes = full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count().index
    if "m" in indexes and "f" in indexes:
        top_female_movies["m"+str(i)] = full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count()["f"] / (full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count()["f"] + full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count()["m"])
    elif "f" not in indexes and "m" in indexes:
        top_female_movies["m"+str(i)] = 0
    elif "m" not in indexes and "f" in indexes:
        top_female_movies["m"+str(i)] = 1
    else:
        top_female_movies["m"+str(i)] = "N/A"

# %%
for i in range(617):
    indexes = full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count().index
    if full_data[full_data["movie_id"] == "m"+str(i)]["line_id"].count() < 120:
        top_female_movies["m"+str(i)] = "N/A"
    elif "m" in indexes and "f" in indexes and "?" in indexes:
        if full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count()["?"] > (full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count()["m"] + full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count()["f"]):
            top_female_movies["m"+str(i)] = "N/A"
    elif "f" in indexes and "?" in indexes:
        if full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count()["?"] > (full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count()["f"])*2:
            top_female_movies["m"+str(i)] = "N/A"
    elif "m" in indexes and "?" in indexes:
        if full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count()["?"] > (full_data[full_data["movie_id"] == "m"+str(i)].groupby("corrected_gender")["line_id"].count()["m"])*2:
            top_female_movies["m"+str(i)] = "N/A"

# %%
full_data[full_data["movie_title"] == "alien vs. predator"].groupby("corrected_gender")["line_id"].count()
# Out:
# corrected_gender
# ?    251
# f     32
# Name: line_id, dtype: int64

# %%
top_female_movies_c = {k:v for k,v in top_female_movies.items() if v != 'N/A'}
        
top_female_movies_sort = dict(sorted(top_female_movies_c.items(), key=lambda item: item[1], reverse=True))

top_10 = list(top_female_movies_sort.keys())[0:10]
no_females = [k for k, v in top_female_movies_sort.items() if v == 0]

# %%
titles["percent_female"] = titles["movie_id"].map(top_female_movies_sort)

# %%
top_females_df = titles[titles["percent_female"] != "N/A"].sort_values("percent_female", ascending=False).head(10)[["movie_title", "genres", "percent_female"]]
top_females_df["movie_title"] = top_females_df["movie_title"].str.upper()
# Out:
# C:\Users\Sophia\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
top_females_df.reset_index()[["movie_title", "genres", "percent_female"]]
top_females_df.index = (np.arange(1,11))
pd.set_option('display.max_colwidth', 0)
#top_females_df['percent_female'] = pd.Series(["{0:.2f}%".format(val * 100) for val in top_females_df['percent_female']], index = top_females_df.index)
dfi.export(top_females_df, "images/top_movies_female.png")

# %%
top_females_df
# Out:
#                                            movie_title  \
# 1   AGNES OF GOD
# 2   HEAVENLY CREATURES
# 3   SUGAR & SPICE
# 4   MY MOTHER DREAMS THE SATAN'S DISCIPLES IN NEW YORK
# 5   DROP DEAD GORGEOUS
# 6   HELLRAISER III: HELL ON EARTH
# 7   THELMA & LOUISE
# 8   STEPMOM
# 9   FRIDAY THE 13TH PART III
# 10  I STILL KNOW WHAT YOU DID LAST SUMMER
#
#                                     genres  percent_female
# 1   ['drama' 'mystery' 'thriller']          0.990208
# 2   ['crime' 'drama' 'fantasy' 'thriller']  0.897561
# 3   ['comedy' 'crime']                      0.890476
# 4   ['short']                               0.884956
# 5   ['comedy' 'adult']                      0.875648
# 6   ['horror']                              0.868132
# 7   ['crime' 'drama' 'thriller']            0.847487
# 8   ['comedy' 'drama']                      0.792142
# 9   ['horror']                              0.777778
# 10  ['horror' 'mystery' 'thriller']         0.770751

# %%
genre_corr_dict = dict()
for x in genres_set:
    if len(genre_dict[x]["movie_id"].unique()) >= 5:
        genre_corr_dict[x] = (genre_titles_dict[x][["rating", "percent_female"]])

# %%
full_data.loc[full_data.corrected_gender == "f"]["percent_female"]

# %%
full_data.loc[full_data.corrected_gender == "f"]["percent_female"]

# %%
dist = stats.norm(100, 15/np.sqrt(n))
1 - dist.cdf(112)

x2 = np.linspace(0,1)
ax.plot(x2, dist.pdf(x2))
ax.set_title('Normal Mean 100')
ax.fill_between(x2, dist.pdf(x2), where = x2>dist.ppf(0.95), alpha = 0.5, color = 'r')
ax.axvline(112, color = 'g');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1097-9b352d43baa4> in <module>
#       1 x2 = np.linspace(0,1)
# ----> 2 ax.plot(x2, dist.pdf(x2))
#       3 ax.set_title('Normal Mean 100')
#       4 ax.fill_between(x2, dist.pdf(x2), where = x2>dist.ppf(0.95), alpha = 0.5, color = 'r')
#       5 ax.axvline(112, color = 'g');
#
# NameError: name 'dist' is not defined

# %%
len(full_data["movie_id"].unique())
# Out:
# 606

# %%
titles[["rating", "percent_female"]]
# Out:
#      rating  percent_female
# 0    6.9     0.445652
# 1    6.2     0.163158
# 2    6.1     0.168654
# 3    8.4     0.033654
# 4    6.9     0.157895
# ..   ...          ...
# 610  8.3     0.419878
# 611  6.3     0.303030
# 612  7.8     0.329114
# 613  5.6     0.197101
# 615  8.0     0.247444
#
# [570 rows x 2 columns]

# %%
fig, axes = plt.subplots(ncols=4, nrows=5, figsize=(10,6), )

for genre, ax in zip(genre_corr_dict, axes.flat):
    cbar_ax = fig.add_axes([.92, 0.1, .03, 0.75])
    corr = genre_corr_dict[genre][["rating", "percent_female"]].corr().drop(["rating"], axis=1).drop("percent_female", axis=0)
    sns.heatmap(corr, vmin=-0.5, vmax=0.5, annot=True, annot_kws={"fontsize":15}, ax=ax, cmap="coolwarm", cbar_ax=cbar_ax).set(title=genre, xticks=[], yticks=[])
fig.suptitle("Heatmap of Correlation between Rating and Number of Female Lines", x=0.45, y=1.05, fontsize=18)
plt.gcf().subplots_adjust(bottom=0.5)
plt.tight_layout(rect=[0, 0, .9, 1])
plt.savefig("images/heatmap_rating_lines.png")
# Out:
# <ipython-input-704-a614910f7df8>:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   cbar_ax = fig.add_axes([.92, 0.1, .03, 0.75])
# <ipython-input-704-a614910f7df8>:9: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, .9, 1])

# %%
g = sns.relplot(x="percent_female", y="rating", data=titles[["rating", "percent_female"]]).set(title="Correlation between Rating and Number of Female Lines")
g.fig.set_figwidth(6)
g.fig.set_figheight(6)
plt.tight_layout()
plt.savefig("images/corr_rating_female_lines.png", dpi=300)

# %%
sns.distplot(titles[["rating"]])
sns.distplot(titles[["percent_female"]]*10)
#.set(title="Correlation between Rating and Number of Female Lines")
#g.fig.set_figwidth(6)
#g.fig.set_figheight(6)
plt.tight_layout()
plt.show()
#plt.savefig("images/corr_rating_female_lines.png", dpi=300)
# Out:
# C:\Users\Sophia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sophia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
titles_genres_df = pd.DataFrame()
titles_genres_dict = dict()

for i in range(len(titles)+1):
    for genre in genres_set:
        if len(titles.loc[titles.movie_id=="m"+str(i)]["genres"]) > 0:
            if genre in titles.loc[titles.movie_id=="m"+str(i)]["genres"].iloc[0]:
                titles.loc[titles.movie_id=="m"+str(i), "genre"] = genre
                titles_genres_df = titles_genres_df.append(titles.loc[titles.movie_id=="m"+str(i)])

# %%
titles_genres_df
# Out:
#     movie_id                 movie_title movie_year  rating    votes  \
# 0    m0       10 things i hate about you  1999       6.9     62847.0
# 0    m0       10 things i hate about you  1999       6.9     62847.0
# 1    m1       1492: conquest of paradise  1992       6.2     10421.0
# 1    m1       1492: conquest of paradise  1992       6.2     10421.0
# 1    m1       1492: conquest of paradise  1992       6.2     10421.0
# ..   ..                              ...   ...       ...         ...
# 570  m570     three kings                 1999       7.3     69757.0
# 570  m570     three kings                 1999       7.3     69757.0
# 570  m570     three kings                 1999       7.3     69757.0
# 570  m570     three kings                 1999       7.3     69757.0
# 570  m570     three kings                 1999       7.3     69757.0
#
#                                             genres  percent_female      genre
# 0    ['comedy' 'romance']                           0.445652        romance
# 0    ['comedy' 'romance']                           0.445652        comedy
# 1    ['adventure' 'biography' 'drama' 'history']    0.163158        history
# 1    ['adventure' 'biography' 'drama' 'history']    0.163158        adventure
# 1    ['adventure' 'biography' 'drama' 'history']    0.163158        biography
# ..                                           ...         ...              ...
# 570  ['action' 'adventure' 'comedy' 'drama' 'war']  0.000000        comedy
# 570  ['action' 'adventure' 'comedy' 'drama' 'war']  0.000000        action
# 570  ['action' 'adventure' 'comedy' 'drama' 'war']  0.000000        war
# 570  ['action' 'adventure' 'comedy' 'drama' 'war']  0.000000        adventure
# 570  ['action' 'adventure' 'comedy' 'drama' 'war']  0.000000        drama
#
# [1571 rows x 8 columns]

# %%
def lemmatizer(text):
    punct = '''!@#$%^&*()_--+=...,?/"'[]\:;<>'''
    lst_master = []
    for x in text:
        if (str(x)) != "nan":
            lst = []
            for word, tag in pos_tag(word_tokenize(x)):
                wntag = tag[0].lower()
                wntag = wntag if wntag in ['a', 'r', 'n', 'v'] else None
                lemma = wnl.lemmatize(word, wntag) if wntag else word
                if lemma not in punct:
                    lst.append(lemma)
            lst_master.append(" ".join([x.lower() for x in lst]))
        else:
            lst_master.append(" ")
    return lst_master

# %%
def no_stopwords(text):
    lst_master = []
    for x in text:
        if (str(x)) != "nan":
            lst = []
            for word in x.split(" "):
                if word.lower() not in stop_words:
                    lst.append(word)
            lst_master.append(" ".join([x.lower() for x in lst]))
        else:
            lst_master.append(" ")
    return lst_master

# %%
full_data["cleaned"] = [x for x in lemmatizer(full_data["text"].values)]

# %%
full_data["cleaned_no_stops"] = [x for x in no_stopwords(full_data["cleaned"].values)]

# %%
full_data[["text", "cleaned", "cleaned_no_stops"]]
# Out:
#                                                                                        text  \
# 0       They do not!
# 1       I hope so.
# 2       Let's go.
# 3       Okay -- you're gonna need to learn how to lie.
# 4       Like my fear of wearing pastels?
# ...                                  ...
# 283245  Now just one moment.  There's no need for roughhousing.  Have you ever tried a tip?
# 283246  Oh no sir-ee.  If yo don't have a reservation you can skip to ma-loo.
# 283247  I'm sorry sir.  We only seat by reservation.
# 283248  Do you have a reservation?
# 283249  Yes sir name please?
#
#                                                                             cleaned  \
# 0       they do not
# 1       i hope so
# 2       let 's go
# 3       okay you 're gon na need to learn how to lie
# 4       like my fear of wear pastel
# ...                             ...
# 283245  now just one moment there 's no need for roughhouse have you ever try a tip
# 283246  oh no sir-ee if yo do n't have a reservation you can skip to ma-loo
# 283247  i 'm sorry sir we only seat by reservation
# 283248  do you have a reservation
# 283249  yes sir name please
#
#                                cleaned_no_stops
# 0
# 1       hope
# 2       let go
# 3       okay gon na need learn lie
# 4       like fear wear pastel
# ...                       ...
# 283245  one moment need roughhouse ever try tip
# 283246  oh sir-ee yo reservation skip ma-loo
# 283247  sorry sir seat reservation
# 283248  reservation
# 283249  yes sir name please
#
# [283250 rows x 3 columns]

# %%
Counter(" ".join(full_data["cleaned_no_stops"]).split()).most_common(25)
# Out:
# [('get', 26953),
#  ('know', 22764),
#  ('go', 20097),
#  ('like', 14295),
#  ('think', 13720),
#  ('want', 12871),
#  ('say', 10696),
#  ('one', 9816),
#  ('well', 9776),
#  ('come', 9644),
#  ('tell', 9517),
#  ('right', 9335),
#  ('see', 9285),
#  ('look', 7760),
#  ('would', 7662),
#  ('take', 7583),
#  ('make', 7467),
#  ('oh', 7296),
#  ('yes', 6927),
#  ('good', 6765),
#  ('time', 6726),
#  ('could', 6686),
#  ('<', 6655),
#  ('>', 6653),
#  ('yeah', 6526)]

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stop_words,
                min_font_size = 10).generate(" ".join(full_data["cleaned_no_stops"].values))

# %%
wordcloud_f = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stop_words,
                min_font_size = 10).generate(" ".join(full_data.loc[full_data.corrected_gender == "f"]["cleaned_no_stops"].values))

# %%
wordcloud_m = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stop_words,
                min_font_size = 10).generate(" ".join(full_data.loc[full_data.corrected_gender == "m"]["cleaned_no_stops"].values))

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud_f)
plt.axis("off")
plt.title("Wordcloud of Women's Lines", fontsize=24)
plt.tight_layout(pad = 0)
plt.savefig("images/wordcloud_f.png", dpi=300)

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud_m)
plt.axis("off")
plt.title("Wordcloud of Men's Lines", fontsize=24)
plt.tight_layout(pad = 0)
plt.savefig("images/wordcloud_m.png", dpi=300)

# %%
top_words_f = pd.DataFrame(Counter(" ".join(full_data[full_data.corrected_gender == "f"]["cleaned_no_stops"]).split()).most_common(15))
top_words_f.index = (np.arange(1,16))
top_words_f.columns = ["word", "count"]
dfi.export(top_words_f, "images/top_words_f.png")
top_words_f
# Out:
#      word  count
# 1   know   5966
# 2   get    5822
# 3   go     5510
# 4   like   4008
# 5   think  3915
# 6   want   3582
# 7   say    2728
# 8   oh     2705
# 9   well   2432
# 10  tell   2418
# 11  come   2388
# 12  see    2259
# 13  one    2175
# 14  right  2091
# 15  would  2015

# %%
top_words_m = pd.DataFrame(Counter(" ".join(full_data[full_data.corrected_gender == "m"]["cleaned_no_stops"]).split()).most_common(15))
top_words_m.index = (np.arange(1,16))
top_words_m.columns = ["word", "count"]
dfi.export(top_words_m, "images/top_words_m.png")
top_words_m
# Out:
#      word  count
# 1   get    17189
# 2   know   13824
# 3   go     11889
# 4   like   8380
# 5   think  8133
# 6   want   7495
# 7   say    6386
# 8   one    6001
# 9   right  5933
# 10  well   5899
# 11  come   5768
# 12  tell   5744
# 13  see    5571
# 14  look   4770
# 15  take   4690

# %%
all_male = nltk.Text(" ".join(full_data[full_data.corrected_gender == "m"]["cleaned_no_stops"]).split())

# %%
all_male
# Out:
# <Text: okay wow figure get good stuff eventually thank...>

# %%
sentiment_f = []
sentiment_m = []

for sentence in full_data.loc[full_data.corrected_gender == "m"]["cleaned"]:
    ss = sid.polarity_scores(sentence)
    sentiment_m.append(ss['compound'])
    
for sentence in full_data.loc[full_data.corrected_gender == "f"]["cleaned"]:
    ss = sid.polarity_scores(sentence)
    sentiment_f.append(ss['compound'])

# %%
plt.figure(figsize=[12,5])
ax = sns.distplot(sentiment_f, color="deeppink", label="Female")
ax = sns.distplot(sentiment_m, color="blue", label="Male")
ax.legend(labels=["Female", "Male"])
plt.tight_layout()
plt.savefig("images/sentiment_dist.png", dpi=300)
# Out:
# C:\Users\Sophia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sophia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=[12,5])
ax = sns.distplot([x for x in sentiment_f if x != 0], color="deeppink", label="Female")
ax = sns.distplot([x for x in sentiment_m if x != 0], color="blue", label="Male")
ax.legend(labels=["Female", "Male"])
plt.tight_layout()
plt.savefig("images/sentiment_dist_no_zeroes.png", dpi=300)
# Out:
# C:\Users\Sophia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sophia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=[12,5])
ax = sns.violinplot(x=sentiment_f, orient="h")
#ax = sns.swarmplot(x=sentiment_f, orient="h")
#sns.swarmplot(sentiment_m, color="blue")
ax.legend(labels=["Female", "Male"])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=[12,5])
ax = sns.violinplot(x=sentiment_m, orient="h")
#ax = sns.swarmplot(x=sentiment_m, orient="h")
#sns.swarmplot(sentiment_m, color="blue")
ax.legend(labels=["Female", "Male"])
plt.tight_layout()
plt.show()

# %%
sentiment_f_romance = []
sentiment_m_romance = []

for sentence in full_data.loc[full_data.genres.str.contains("romance")][full_data.corrected_gender == "m"]["cleaned"]:
    ss = sid.polarity_scores(sentence)
    sentiment_m_romance.append(ss['compound'])
    
for sentence in full_data.loc[full_data.genres.str.contains("romance")][full_data.corrected_gender == "f"]["cleaned"]:
    ss = sid.polarity_scores(sentence)
    sentiment_f_romance.append(ss['compound'])
# Out:
# <ipython-input-1053-d133953192b3>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   for sentence in full_data.loc[full_data.genres.str.contains("romance")][full_data.corrected_gender == "m"]["cleaned"]:
# <ipython-input-1053-d133953192b3>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   for sentence in full_data.loc[full_data.genres.str.contains("romance")][full_data.corrected_gender == "f"]["cleaned"]:

# %%
plt.figure(figsize=[12,5])
ax = sns.distplot([x for x in sentiment_f_romance], color="deeppink", label="Female")
ax = sns.distplot([x for x in sentiment_m_romance], color="blue", label="Male")
ax.legend(labels=["Female", "Male"])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Sophia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sophia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
corpus_f = Corpus(utterances=list(full_data.loc[full_data.corrected_gender == "f"]["text"].values))
#corpus_m = Corpus(utterances=list(full_data.loc[full_data.corrected_gender == "m"]["text"].values))
